# %% [markdown]
# # Ejercicio 1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # a)

# %% [markdown]
# * La cantidad de ejemplos utilizados se puede saber sumando todos los valores. -> tenemos 152 ejemplos utilizados
#
# * Puede reconocer correctamente todos los q estan en la diagonal de la matriz. Es decir 17 + 12 + 12 + 38 + 61 = 140
#
# * la suma de la diagonal dividido la cantidad de ejemplos: 0.92
#
# * Respectivamente 17/19 , 12/20 , 12/13 , 38/38, 61/62
#
# * 17/19, 12/12, 12/12, 38/40, 61/69
# # b)

# %%
pre = [17/19, 12/20, 12/13, 1, 61/62]
rec = [17/19, 1, 1, 38/40, 61/69]

max = 0
i_max = 0

for i in range(0, pre.__len__()):
    if (2 * (pre[i] * rec[i])/(pre[i] + rec[i])) > max:
        max = (2 * (pre[i] * rec[i])/(pre[i] + rec[i]))
        i_max = i

print(max, i)
# Out:
# 0.9743589743589743 4

# %% [markdown]
# Podemos ver que el elemento 4, es decir 3ra fila y tercera columna (Clase 3) es la que tiene mejor F1
